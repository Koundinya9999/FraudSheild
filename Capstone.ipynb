# %%
pip install pdfminer.six
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import io
import pdfminer
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage

def read_privacy_policy(file_path):
    content = ""

    with open(file_path, 'rb') as file:
        resource_manager = PDFResourceManager()
        text_stream = io.StringIO()
        converter = TextConverter(resource_manager, text_stream)
        interpreter = PDFPageInterpreter(resource_manager, converter)

        for page in PDFPage.get_pages(file):
            interpreter.process_page(page)

        content = text_stream.getvalue().lower()

    controls = {
        "access": False,
        "correct/ update": False,
        "delete": False,
        "portability": False,
        "opt/ withdraw": False,
        "choose/ select": False,
        "age/ child/ minor": False,
        "Notice/transparency/ purpose": False,
        "breach": False,
        "purpose": False,
        "record": False,
        "international": False
    }
    
    for control in controls:
        if control in content:
            controls[control] = True

    return controls

# Provide the file path of your privacy policy document
file_path = "/Users/tanya/Downloads/Dropbox privacy policy.pdf"

# Read the document and get the results
results = read_privacy_policy(file_path)

# Print the results
for control, presence in results.items():
    print(f"{control}: {'Present' if presence else 'Not Present'}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Kound\OneDrive\Desktop\Capstone\New folder\Capstone.ipynb Cell 2 in <cell line: 46>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Kound/OneDrive/Desktop/Capstone/New%20folder/Capstone.ipynb#W1sZmlsZQ%3D%3D?line=42'>43</a> file_path = "/Users/tanya/Downloads/Dropbox privacy policy.pdf"
#      <a href='vscode-notebook-cell:/c%3A/Users/Kound/OneDrive/Desktop/Capstone/New%20folder/Capstone.ipynb#W1sZmlsZQ%3D%3D?line=44'>45</a> # Read the document and get the results
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Kound/OneDrive/Desktop/Capstone/New%20folder/Capstone.ipynb#W1sZmlsZQ%3D%3D?line=45'>46</a> results = read_privacy_policy(file_path)
#      <a href='vscode-notebook-cell:/c%3A/Users/Kound/OneDrive/Desktop/Capstone/New%20folder/Capstone.ipynb#W1sZmlsZQ%3D%3D?line=47'>48</a> # Print the results
# ...

# %%
import PyPDF2
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/tanya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/tanya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
pip install PyMuPDF
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
from pdfminer.high_level import extract_text

# Function to extract controls from a privacy policy document
def extract_controls(document_path):
    controls = {
        "access": False,
        "correct/ update": False,
        "delete": False,
        "portability": False,
        "opt/ withdraw": False,
        "choose/ select": False,
        "age/ child/ minor": False,
        "Notice/transparency/ purpose": False,
        "breach": False,
        "purpose": False,
        "record": False,
        "international": False
    }

    # Extract text from the PDF document
    text = extract_text(document_path)

    # Check for the presence of controls in the text
    for control in controls.keys():
        if re.search(control, text, re.IGNORECASE):
            controls[control] = True

    return controls

# Directory containing the privacy policy documents
directory = "/Users/tanya/Downloads/Privacy policies"

# Iterate over the PDF files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".pdf"):
        document_path = os.path.join(directory, filename)
        
        # Extract controls from the document
        controls = extract_controls(document_path)

        # Print the results for the document
        print(f"Document: {filename}")
        for control, value in controls.items():
            print(f"{control}: {value}")
        print("----------------------------------------")
# Out:
# Document: Intuit Privacy policy.pdf
# access: True
# correct/ update: False
# delete: True
# portability: False
# opt/ withdraw: False
# choose/ select: False
# age/ child/ minor: False
# Notice/transparency/ purpose: False
# breach: False
# purpose: True
# record: True
# international: True
# ----------------------------------------
# Document: NextOSPrivacyPolicy.pdf
# access: True
# correct/ update: False
# delete: True
# portability: False
# opt/ withdraw: False
# choose/ select: False
# age/ child/ minor: False
# Notice/transparency/ purpose: False
# breach: True
# purpose: True
# record: True
# international: False
# ----------------------------------------
# Document: Skype privacy policy.pdf
# access: True
# correct/ update: False
# delete: True
# portability: False
# opt/ withdraw: False
# choose/ select: False
# age/ child/ minor: False
# Notice/transparency/ purpose: False
# breach: False
# purpose: True
# record: False
# international: False
# ...

# %%
#Data Processing

# %%
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z]', ' ', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [token for token in tokens if token not in stop_words]

    # Join the filtered tokens back into a single text
    preprocessed_text = ' '.join(filtered_tokens)

    return preprocessed_text

# Provide the path to your privacy policy folder
privacy_policy_folder = '/Users/tanya/Downloads/Privacy policies'

# Process each privacy policy document
for filename in os.listdir(privacy_policy_folder):
    file_path = os.path.join(privacy_policy_folder, filename)

    # Try different encodings until the file can be read successfully
    encodings = ['utf-8', 'latin-1']
    text = None

    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as file:
                text = file.read()
            break
        except UnicodeDecodeError:
            continue

    if text is None:
        print(f"Error reading file: {filename}")
        continue

    # Preprocess the text
    preprocessed_text = preprocess_text(text)

    # Print the preprocessed text
    print(f"Preprocessed text for {filename}:")
    print(preprocessed_text)
    print()
# Out:
# [nltk_data] Downloading package punkt to /Users/tanya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/tanya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Preprocessed text for Intuit Privacy policy.pdf:
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z]', ' ', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [token for token in tokens if token not in stop_words]

    # Join the filtered tokens back into a single text
    preprocessed_text = ' '.join(filtered_tokens)

    return preprocessed_text

# Provide the path to your privacy policy folder
privacy_policy_folder = '/Users/tanya/Downloads/Privacy policies'

# Process each privacy policy document
preprocessed_texts = []

for filename in os.listdir(privacy_policy_folder):
    file_path = os.path.join(privacy_policy_folder, filename)

    # Try different encodings until the file can be read successfully
    encodings = ['utf-8', 'latin-1']
    text = None

    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as file:
                text = file.read()
            break
        except UnicodeDecodeError:
            continue

    if text is None:
        print(f"Error reading file: {filename}")
        continue

    # Preprocess the text
    preprocessed_text = preprocess_text(text)
    preprocessed_texts.append(preprocessed_text)

# Create a TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Generate TF-IDF matrix
tfidf_matrix = vectorizer.fit_transform(preprocessed_texts)

# Get the feature names from the vectorizer's vocabulary
feature_names = vectorizer.vocabulary_.keys()

# Print the feature names
print("Feature names:")
print(list(feature_names))
# Out:
# [nltk_data] Downloading package punkt to /Users/tanya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/tanya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Feature names:
# ...

# %%
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z]', ' ', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [token for token in tokens if token not in stop_words]

    # Join the filtered tokens back into a single text
    preprocessed_text = ' '.join(filtered_tokens)

    return preprocessed_text

# Provide the path to your privacy policy folder
privacy_policy_folder = '/Users/tanya/Downloads/Privacy policies'

# Process each privacy policy document
preprocessed_texts = []
labels = []

for filename in os.listdir(privacy_policy_folder):
    file_path = os.path.join(privacy_policy_folder, filename)

    # Try different encodings until the file can be read successfully
    encodings = ['utf-8', 'latin-1']
    text = None

    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as file:
                text = file.read()
            break
        except UnicodeDecodeError:
            continue

    if text is None:
        print(f"Error reading file: {filename}")
        continue

    # Preprocess the text
    preprocessed_text = preprocess_text(text)
    preprocessed_texts.append(preprocessed_text)

    # Assign label based on the presence of controls
    label = 1 if any(control in preprocessed_text for control in controls) else 0
    labels.append(label)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(preprocessed_texts, labels, test_size=0.2, random_state=42)

# Create a TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Generate TF-IDF matrices for training and testing sets
tfidf_matrix_train = vectorizer.fit_transform(X_train)
tfidf_matrix_test = vectorizer.transform(X_test)

# Train the MultinomialNB classifier
classifier = MultinomialNB()
classifier.fit(tfidf_matrix_train, y_train)

# Make predictions on the testing set
y_pred = classifier.predict(tfidf_matrix_test)

# Evaluate the model
accuracy = metrics.accuracy_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred)
recall = metrics.recall_score(y_test, y_pred)
f1_score = metrics.f1_score(y_test, y_pred)

# Print the evaluation metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1_score)
# Out:
# [nltk_data] Downloading package punkt to /Users/tanya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/tanya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Accuracy: 0.5
# Precision: 0.5
# Recall: 1.0
# F1-score: 0.6666666666666666

# %%
pip install spacy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 33.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 28.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 47.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.9/491.9 kB 45.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.1/859.1 kB 44.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 22.4 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy

# Load the trained model
nlp = spacy.load('your_trained_model')

# Define the controls
controls = {
    "access": False,
    "correct/update": False,
    "delete": False,
    "portability": False,
    "opt/withdraw": False,
    "choose/select": False,
    "age/child/minor": False,
    "Notice/transparency/purpose": False,
    "breach": False,
    "purpose": False,
    "record": False,
    "international": False
}

# Function to extract controls from a privacy policy document
def extract_controls(doc):
    extracted_controls = dict(controls)

    # Perform the necessary text preprocessing on the document if required
    processed_text = preprocess_text(doc)

    # Pass the preprocessed text through the trained model for prediction
    predicted_labels = nlp(processed_text)

    # Update the extracted controls based on the predicted labels
    for label in predicted_labels:
        if label in extracted_controls:
            extracted_controls[label] = True

    return extracted_controls

# Example usage
privacy_policy_path = '/path/to/privacy_policy.pdf'

# Read the privacy policy document
with open(privacy_policy_path, 'r') as file:
    document_text = file.read()

# Extract controls from the privacy policy document
extracted_controls = extract_controls(document_text)

# Print the extracted controls
for control, value in extracted_controls.items():
    print(f"{control}: {value}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[51], line 4
#       1 import spacy
#       3 # Load the trained model
# ----> 4 nlp = spacy.load('your_trained_model')
#       6 # Define the controls
#       7 controls = {
#       8     "access": False,
#       9     "correct/update": False,
#    (...)
#      19     "international": False
#      20 }
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#    (...)
#      52     RETURNS (Language): The loaded nlp object.
# ...
